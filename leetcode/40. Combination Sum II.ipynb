// %% [markdown]
// https://leetcode.com/problems/combination-sum-ii
//
//
// Runtime: 208 ms, faster than 8.98% of Go online submissions for Combination Sum II.
// Memory Usage: 12.1 MB, less than 5.39% of Go online submissions for Combination Sum II.
//
//
// ```go
// package main
//
// import (
// 	"fmt"
// 	"sort"
// )
//
// func sum(nums []int) int {
// 	value := 0
// 	for _, n := range nums {
// 		value += n
// 	}
// 	return value
// }
//
// func remove(nums []int, target int) []int {
// 	ok := false
// 	result := make([]int, 0)
// 	for _, n := range nums {
// 		if n == target {
// 			if ok == true {
// 				result = append(result, n)
// 			} else {
// 				ok = true
// 			}
// 		} else {
// 			result = append(result, n)
// 		}
// 	}
// 	return result
// }
//
// func Equal(a, b []int) bool {
// 	if len(a) != len(b) {
// 		return false
// 	}
// 	for i, v := range a {
// 		if v != b[i] {
// 			return false
// 		}
// 	}
// 	return true
// }
//
// func contains(arr [][]int, value []int) bool {
// 	for _, v := range arr {
// 		if Equal(v, value) {
// 			return true
// 		}
// 	}
//
// 	return false
// }
//
// var result = make([][]int, 0)
// var the_target = 0
//
// func go_through(this_list []int, list_left []int) {
// 	if len(list_left) == 0 {
// 		return
// 	} else {
// 		copy_of_list_left := list_left
// 		for _, num := range copy_of_list_left {
//             new_list := make([]int, 0)
// 			new_list = append(new_list, this_list...)
// 			new_list = append(new_list, num)
// 			s := sum(new_list)
// 			if s > the_target {
// 				return
// 			} else if s == the_target {
// 				sort.Ints(new_list)
// 				result = append(result, new_list)
// 			} else {
// 				l := list_left
// 				l = remove(l, num)
// 				go_through(new_list, l)
// 			}
// 		}
// 	}
// }
//
// func combinationSum2(candidates []int, target int) [][]int {
// 	//8:59
// 	result = result[:0]
// 	the_target = target
//
// 	if sum(candidates) < target {
// 		return result
// 	}
//
// 	sort.Ints(candidates)
// 	l := make([]int, 0)
// 	go_through(l, candidates)
//
// 	new_result := make([][]int, 0)
// 	for _, l := range result {
// 		have_it := contains(new_result, l)
// 		if have_it {
// 		} else {
// 			new_result = append(new_result, l)
// 		}
// 	}
// 	return new_result
// 	//9:19
//     //debug until 9:45
//     //debug at second day morning, 7:30 to 7:50, found that for golang, if you do not use make() to create array, that array will get random value (because of memory release) after the end of its function
// }
// ```
