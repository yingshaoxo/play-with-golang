// %% [markdown]
// https://leetcode.com/problems/min-stack
//
//
//
// Runtime: 44 ms, faster than 10.83% of Go online submissions for Min Stack.
// Memory Usage: 7.5 MB, less than 50.42% of Go online submissions for Min Stack.
//
//
//
// ```go
// package main
//
// import "errors"
//
// func Min(values []int) (min int, e error) {
// 	if len(values) == 0 {
// 		return 0, errors.New("Cannot detect a minimum value in an empty slice")
// 	}
//
// 	min = values[0]
// 	for _, v := range values {
// 		if v < min {
// 			min = v
// 		}
// 	}
//
// 	return min, nil
// }
//
// type MinStack struct {
// 	stack []int
// }
//
// /** initialize your data structure here. */
// func Constructor() MinStack {
// 	return MinStack{make([]int, 0)}
// }
//
// func (this *MinStack) Push(x int) {
// 	this.stack = append(this.stack, x)
// }
//
// func (this *MinStack) Pop() {
// 	this.stack = this.stack[:len(this.stack)-1]
// }
//
// func (this *MinStack) Top() int {
// 	return this.stack[len(this.stack)-1]
// }
//
// func (this *MinStack) GetMin() int {
// 	v, _ := Min(this.stack)
// 	return v
// }
// ```
