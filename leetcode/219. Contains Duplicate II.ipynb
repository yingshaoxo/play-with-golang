// %% [markdown]
// https://leetcode.com/problems/contains-duplicate-ii/
//
// Runtime: 28 ms, faster than 23.08% of Go online submissions for Contains Duplicate II.
// Memory Usage: 15.4 MB, less than 8.88% of Go online submissions for Contains Duplicate II.
//
// ```go
// package main
//
// import "fmt"
// import "math"
//
// var length_limit = 0
// var result = make([][]int, 0)
//
// func loop(l []int, n int, left_list []int) {
// 	if n == length_limit {
// 		return
// 	}
// 	for i, e := range left_list {
// 		var new = append(l, e)
// 		if len(new) == length_limit {
// 			result = append(result, new)
// 		}
// 		loop(new, n+1, left_list[i+1:])
// 	}
// }
//
// func my_combinations(source_list []int, length int) [][]int {
// 	result = result[:0]
// 	length_limit = length
// 	loop([]int{}, 0, source_list)
// 	return result
// }
//
// func containsNearbyDuplicate(nums []int, k int) bool {
// 	//8:58
//     if len(nums) == 1 {
//         return false
//     }
// 	var num_dict = make(map[int][]int)
//     var all_one = true
// 	for  i, n := range nums {
//         if n != 1 {
//             all_one = false
//         }
// 		_, exists := num_dict[n]
// 		if exists {
// 			num_dict[n] = append(num_dict[n], i)
// 		} else  {
// 			num_dict[n] = []int{i}
// 		}
// 	}
//     if (all_one) {
//         return true
//     }
// 	for _, value := range num_dict {
// 		if len(value) >= 2 {
// 			for _, combination := range my_combinations(value, 2) {
//                 if int(math.Abs(float64(combination[0]) - float64(combination[1]))) <= k {
// 					return true;
// 				}
// 			}
// 		}
// 	}
// 	return false;
//     //9:12
// }
// ```
